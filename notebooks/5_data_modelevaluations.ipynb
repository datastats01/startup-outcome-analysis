# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## Model Comparison Table
#
# | Model               | Accuracy | Precision (weighted) | Recall (weighted) | F1 Score (weighted) | ROC AUC |
# |---------------------|----------|----------------------|-------------------|---------------------|---------|
# | Logistic Regression | 0.7447   | 0.7417               | 0.7447            | 0.7403              | 0.745   |
# | Random Forest       | 0.7362   | 0.7345               | 0.7362            | 0.7291              | 0.786   |
#
# ---

# %% [markdown]
# ## 📊 Logistic Regression Evaluation
#
# ### Key Insights:
#
# - **Moderate overall performance** with around **74% accuracy**.
# - Best at predicting **Failure**, with **high recall** (0.83) and **precision** (0.76).
# - Struggles with **IPO prediction**, with **low recall** (27%) for IPO.
# - **Class imbalance** heavily impacts **IPO** performance, where **many IPO cases are missed**.
#
# ### Metrics:
#
# - **Accuracy**: 0.7447
# - **Precision (weighted)**: 0.7417
# - **Recall (weighted)**: 0.7447
# - **F1 Score (weighted)**: 0.7403
# - **ROC AUC**: 0.745
#
# ### Confusion Matrix:
#
# | Actual \ Predicted | Acquisition | Failure | IPO |
# |--------------------|-------------|---------|-----|
# | Acquisition        | 5572        | 2839    | 56  |
# | Failure            | 1910        | 9211    | 1   |
# | IPO                | 300         | 1       | 110 |
#
# ### Class-wise Performance:
#
# - **✔ Best Performing Class: Failure**
#     - **Precision**: 0.76
#     - **Recall**: 0.83
#     - **F1-score**: 0.79
#
# - **⚠ Weakest Performing Class: IPO**
#     - **Precision**: 0.66
#     - **Recall**: 0.27
#     - **F1-score**: 0.38
#
# ### Conclusion:
#
# - **Logistic Regression** shows **moderate performance** with around **74% accuracy**, which is reasonable for this dataset.
# - Best at predicting **Failure**, but **struggles with IPO** due to **class imbalance** and **misses many IPO cases**.
#
# ---

# %% [markdown]
# ## 🌲 Random Forest Evaluation
#
# ### Key Insights:
#
# - **Similar to Logistic Regression**, with slight differences in performance (~73–74% accuracy).
# - **Failure** is the easiest class to predict, with **high recall** (0.82).
# - **IPO prediction remains weak**, with even **worse recall** than Logistic Regression (0.09).
# - **No clear advantage over Logistic Regression** for this dataset, particularly for **IPO prediction**.
#
# ### Metrics:
#
# - **Accuracy**: 0.7362
# - **Precision (weighted)**: 0.7345
# - **Recall (weighted)**: 0.7362
# - **F1 Score (weighted)**: 0.7291
# - **ROC AUC**: 0.786
#
# ### Confusion Matrix:
#
# | Actual \ Predicted | Acquisition | Failure | IPO |
# |--------------------|-------------|---------|-----|
# | Acquisition        | 5576        | 2879    | 12  |
# | Failure            | 2010        | 9112    | 0   |
# | IPO                | 374         | 1       | 36  |
#
# ### Class-wise Performance:
#
# - **✔ Best Performing Class: Failure**
#     - **Precision**: 0.76
#     - **Recall**: 0.82
#     - **F1-score**: 0.79
#
# - **⚠ Weakest Performing Class: IPO**
#     - **Precision**: 0.75
#     - **Recall**: 0.09
#     - **F1-score**: 0.16
#
# ### Conclusion:
#
# - Both models perform similarly (~73–74% accuracy), with **Failure** being the easiest class to predict.
# - **Random Forest** has **slightly worse IPO recall** than **Logistic Regression**.
#
# ---

# %% [markdown]
# ## 🔑 Feature Importance Evaluation
#
# ### Key Insights:
#
# - **Revenue** and **product traction** are the most influential features in predicting startup outcomes.
# - **Founder background** and **investor type** have **low importance** in predictions.
# - The model is heavily driven by **financial** and **performance metrics**, rather than **qualitative features**.
#
# ### Feature Importance Table:
#
# | Feature                    | Importance |
# |----------------------------|------------|
# | Revenue (million)           | 0.2684     |
# | Product Traction (users)    | 0.2154     |
# | Founder Experience (years)  | 0.0857     |
# | Team Size                   | 0.0847     |
# | Market Size (billion)       | 0.0797     |
# | Burn Rate (million)         | 0.0794     |
# | Funding Rounds              | 0.0715     |
# | Sector                      | 0.0500     |
# | Investor Type               | 0.0327     |
# | Founder Background          | 0.0326     |

# %% [markdown]
# ### Conclusion:
#
# - **Revenue** and **Product Traction** are the key drivers of success in this dataset.
# - **Financial** and **business performance metrics** are far more important than **qualitative features** like **founder background** or **investor type**.
#
# ---

# %% [markdown]
# ## 🚀 Final Takeaways:
#
# - Both models perform similarly (~73–74% accuracy), with **Failure** being the easiest to predict.
# - Both models struggle with **IPO predictions** due to **class imbalance**.
# - **Key features for prediction**: **Revenue** and **User Traction**.
# - **Next steps**: Address **class imbalance**, explore better **IPO prediction techniques**, and refine features for stronger prediction.
